# %%
import function as f

files = [
  ("http2asynctest.csv", "async", 2),
  ("http3asynctest.csv", "async", 3),
]

f.generate_df(files).T
# Out:
# All HTTP/2 async requests: 1000
# Mismatched HTTP/2 async requests: 0
# Failed HTTP/2 async requests: 0
#
# All HTTP/3 async requests: 1000
# Mismatched HTTP/3 async requests: 448
# Failed HTTP/3 async requests: 1
#                    response_code  http_version  speed_download  speed_upload  \
# HTTP/2 Async Min           200.0           2.0        0.000000           0.0
# HTTP/2 Async Mean          200.0           2.0        0.812000           0.0
# HTTP/2 Async Max           200.0           2.0       13.000000           0.0
# HTTP/3 Async Min           200.0           3.0       10.000000           0.0
# HTTP/3 Async Mean          200.0           3.0       28.358696           0.0
# HTTP/3 Async Max           200.0           3.0       35.000000           0.0
#
#                    time_starttransfer  time_pretransfer  time_appconnect  \
# HTTP/2 Async Min             0.293660          0.186894         0.186814
# ...
