# %%
import function as f

files = [
  ("http3asynctest.csv", "async", 3),
  ("http3synctest.csv", "sync", 3)
]

f.generate_df(files)
# Out:
# All HTTP/3 async requests: 1000
# Mismatched HTTP/3 async requests: 448
# Failed HTTP/3 async requests: 1
#
# All HTTP/3 sync requests: 1000
# Mismatched HTTP/3 sync requests: 5
# Failed HTTP/3 sync requests: 0
#                     HTTP/3 Async Min  HTTP/3 Async Mean  HTTP/3 Async Max  \
# response_code             200.000000         200.000000        200.000000
# http_version                3.000000           3.000000          3.000000
# speed_download             10.000000          28.358696         35.000000
# speed_upload                0.000000           0.000000          0.000000
# time_starttransfer          0.111264           0.142822          0.388517
# time_pretransfer            0.075846           0.092942          0.186938
# time_appconnect             0.073129           0.088961          0.183298
# time_total                  0.111349           0.142945          0.388548
# time_connect                0.000000           0.000000          0.000000
#
# ...
